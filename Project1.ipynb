# %% [markdown]
# Notebook:
#
# Project: Who is hit hardest by Inflation?
# Team Name: Inflators
# Team Members: Sanjana Devakumaran (sanjud), Sanjna Rachakonda (sanjnarachakonda), Tommy Ayers (tlayers21), Johnson Hwang (hjohnson22)
#
# Project Description: This project will dive into who/ what groups are hit the hardest by inflation. We will evaluate and compare inflation trends with wage changes across different industries.
#
# Potential Research Questions:
# - Does inflation affect low-income groups more severely than high-income ones?
# - Do wages keep up with inflation across industries?
#
# Relevant Source Data:
# We have a collection of articles that contain the salaries and wages of different professions and how they have changed in response to inflation in the United States.
# https://usafacts.org/answers/are-wages-keeping-up-with-inflation/country/united-states/ https://fred.stlouisfed.org/tags/series?t=inflation;wages https://www.atlantafed.org/research-and-data/data/wage-growth-tracker https://www.bea.gov/data/prices-inflation/regional-price-parities-state-and-metro-area https://www.bls.gov/news.release/realer.htm https://www.newyorkfed.org/microeconomics/sce
