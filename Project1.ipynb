# %% [markdown]
# # **Part 1**
#
# ## Project Title : Who is hit hardest by Inflation?
# **Team Name** : Inflators
#
# **Team Member Names and PIDs:**
# - Sanjana Devakumaran (sanjud)
# - Sanjna Rachakonda (sanjnarachakonda)
# - Tommy Ayers (tlayers21)
# - Johnson Hwang (hjohnson22)
#
# ## Project introduction:
# **Initial description of the project topic:** This project will dive into who/ what groups are hit the hardest by inflation. We will evaluate and compare inflation trends with wage changes across different industries.
#
# Potential research questions you plan to address:
# - Does inflation affect low-income groups more severely than high-income ones?
# - Do wages keep up with inflation across industries?
#
# Description of potential source data that would be relevant (including links or references if possible):
# - https://usafacts.org/answers/are-wages-keeping-up-with-inflation/country/united-states/
# - https://fred.stlouisfed.org/tags/series?t=inflation;wages
# - https://www.atlantafed.org/research-and-data/data/wage-growth-tracker
# - https://www.bea.gov/data/prices-inflation/regional-price-parities-state-and-metro-area
# - https://www.bls.gov/news.release/realer.htm
# - https://www.newyorkfed.org/microeconomics/sce
