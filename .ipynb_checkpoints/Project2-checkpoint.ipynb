# %% [markdown]
# # Who is hit hardest by Inflation?
# **Team Name:** Inflators
# - Sanjana Devakumaran *(sanjud)*
# - Sanjna Rachakonda *(sanjnarachakonda)*
# - Tommy Ayers *(tlayers21)*
# - Johnson Hwang *(hjohnson22)*
# ## Project Introduction
# This project will investigate which groups are hit the hardest by inflation in the United States. We will evaluate and compare inflation trends with wage changes across different income levels and industries to understand how inflation affects different parts of the population.
# ## Research Questions
# 1. Does inflation affect low-income groups more severely than high-income ones?
# 2. Do wages keep up with inflation across different industries?
# 3. Are certain geographical regions hit harder by inflation than others?
# ## Potential Data Sources
# - FRED - Historical Wages With and Without Inflation: https://fred.stlouisfed.org/tags/series?t=inflation;wages
# - Atlanta FED - Wage Growth: https://www.atlantafed.org/research-and-data/data/wage-growth-tracker
# - BEA – Regional Price Parities: https://www.bea.gov/data/prices-inflation/regional-price-parities-state-and-metro-area
# - BLS - Real Earnings: https://www.bls.gov/news.release/realer.htm

# %% [markdown]
# # Data
# - R-CPI-I: CPI among different household income quintiles (https://www.bls.gov/cpi/research-series/r-cpi-i.htm)

# %%
import pandas

r_cpi_i = pandas.read_excel("data/r-cpi-i-data.xlsx", skiprows=1, header=0, index_col="Year")
r_cpi_i

dfs = []
for quintile in range(1, 6):
    temp = r_cpi_i[['Month', f'R-CPI-I{quintile}']].copy()
    temp.rename(columns={f'R-CPI-I{quintile}': 'CPI'}, inplace=True)
    temp['Quintile'] = quintile
    temp['Year'] = temp.index  # Move Year from index to column
    dfs.append(temp)

# Concatenate all quintile DataFrames
df_long = pd.concat(dfs, ignore_index=True)

# Reorder columns
df_long = df_long[['Year', 'Month', 'Quintile', 'CPI']]
# Out:
#   Cell In[31], line 8
#     temp = r_cpi_i[[Month', f'R-CPI-I{quintile}']].copy()
#                                                ^
# SyntaxError: unterminated string literal (detected at line 8)
